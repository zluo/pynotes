# %% [markdown]
# ### Week One

# %% [markdown]
# ## Course Resources
#
# ### Portfolio Fundamentals
#
# Active Portfolio Management by Grinold & Kahn. Provides solid overview of fundamental quantitative approaches. Good reference for hedge fund managers. Used by Professor Balch in this course.
# Applied Quantitative Methods for Trading and Investment (The Wiley Finance Series) (Hardcover) by Christian L. Dunis (Editor), Jason Laws (Editor), Patrick Naïm (Editor)
#
# Python Tools We Use in the Class
#
# Libraries
#
# Numpy
# Scipy
# scikit-learn
# Matplotlib
# Pandas
#
# Pandas
# 10 Minutes to Pandas - Doc
# Intro to Data Structures – Doc
# Whirlwind tour of pandas in 10 minutes
# 2012 PyData Workshop: Data Analysis in Python with Pandas
# Data analysis in Python with pandas
# Python for Data Analysis
# Time Series Data Analysis with pandas
# Tutorials
#
# NumPy ndarrays
# pandas A library for time series analysis. video
# CheatSheets
#
# Code Examples (Mississippi College)
# How To Ask Questions The Smart Way
# Learning Python
#
# Video Tutorials
#
# Python Fundamentals Screencast series
# Python tutorial videos from Google
# Khan Academy - Computer Science
# Pycon 2010 : Python 101
# Advanced iteration tutorial from Pycon 2013: Loop Like a Native by Ned Batchelder
# Loop like a native: while, for, iterators, generators
# Wes McKinney Data Wrangling Kung Fu With pandas video from PyDataSV
# Chang She Practical Time Series Modeling and Analysis video presentation from PyDataSV
# Books
#
# Practical Programming: An Introduction to Computer Science Using Python
# Python Programming: An Introduction to Computer Science
# Learning Python by Lutz.
# Open book project - Python
# Think Python
# Wes McKinney's book has an appendix with a python overview
# Zed Shaw's "Learn Python the Hard Way"
# Dive into Python
# ipython: IronPython
# Tutorials
# Online Python Introductory Course
# Online Python Study Guide for Programmers
# www.poromenos.org: 10 minute tutorial.
# Possibly useful Python libraries.
# PyProcessing a processing-like environment for doing graphics with Python.
# mayavi for visualization of 3D stuff. Claims to be integrated with SciPy.
# pybrain.org
# Machine Learning library from Technische Universität München. See a video.
# pandas A library for time series analysis. video
# Finance
#
# Financial Magazines
#
# Technical Analysis of Stocks & Commodities
# Futures Magazine
# Active Trader
# Financial Blogs/Sites
#
# Augmented Trader
# Epchan
# The Whole Street
# Eminiming
# Noahpinion
# Pragcap
# Street wise professor
# Testosterone Pit
# Financial Books
#
# "Market Wizards" series, by Jack D. Schwager
# Fortune's Formula
# Reminiscences of a Stock Operator
#
# Terms and Definations
#
# Alpha
# Beta
# Sigma (Standard Deviation) Wikipedia
# Morningstar - Standard Deviation
# Sharpe Ratio
# Investopedia Sharpe Ratio
# Investopedia (Understanding The Sharpe Ratio)
# Morningstar Sharpe Ratio
# Capital Asset Pricing Model (CAPM)
# Vectors
# Brokers for Paper Trading
#
# thinkorswim paper money: Go through the registration process up until they ask for a social security number. You can stop at that point because you now have a valid login. You can login to paper money at page which is linked on the main login screen but isn't immediately obvious.
# Virtual Stock Exchange - MarketWatch: Although the interface is not as good as thinkorswim, it is a good alternative.
# CBOE Paper Trading: Decent paper trading account that allows you to trade options as well as basic equities.
# Historical Data
#
# Norgate: End of day data. Survivor bias free, but only updates once/day. Daily live feed.
# Yahoo! Finance
# EODData
# Quantopian
# Excel addin to pull FRED data directly to spreadsheets
